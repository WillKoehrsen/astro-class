# %%
import numpy as np
import pandas as pd
import featuretools as ft
import featuretools.variable_types as vtypes

import os
PATH = '/home/ubuntu/data/astro/partitions/'

train = pd.read_csv(f'{PATH}ptrain/test_set.csv')
train_meta = pd.read_csv(f'{PATH}ptrain/test_set_metadata.csv')

# %%
train.head()
# Out:
#    object_id         mjd  passband        flux   flux_err  detected
# 0        615  59750.4229         2 -544.810303   3.622952         1
# 1        615  59750.4306         1 -816.434326   5.553370         1
# 2        615  59750.4383         3 -471.385529   3.801213         1
# 3        615  59750.4450         4 -388.984985  11.395031         1
# 4        615  59752.4070         2 -681.858887   4.041204         1

# %%
train_meta.head()
# Out:
#    object_id          ra       decl       gal_l      gal_b  ddf  \
# 0        615  349.046051 -61.943836  320.796530 -51.753706    1
# 1        713   53.085938 -27.784405  223.525509 -54.460748    1
# 2        730   33.574219  -6.579593  170.455585 -61.548219    1
# 3        745    0.189873 -45.586655  328.254458 -68.969298    1
# 4       1124  352.711273 -63.823658  316.922299 -51.059403    1
#
#    hostgal_specz  hostgal_photoz  hostgal_photoz_err  distmod  mwebv  target
# 0         0.0000          0.0000              0.0000      NaN  0.017      92
# 1         1.8181          1.6267              0.2552  45.4063  0.007      88
# 2         0.2320          0.2262              0.0157  40.2561  0.021      42
# 3         0.3037          0.2813              1.1523  40.7951  0.007      90
# 4         0.1934          0.2415              0.0176  40.4166  0.024      90

# %%
class AstroP():
    def __init__(self, partition, train = False, feature_defs = None):
        self.partition = partition
        # Read in data
        self.data = pd.read_csv(f'{PATH}p{partition}/test_set.csv')
        self.metadata = pd.read_csv(f'{PATH}p{partition}/test_set_metadata.csv')
        
        # If training, extract the target and run deep feature synthesis
        if train:
            self.target = np.array(self.metadata.pop('target'))
        
        # Make an entityset
        self.es = self.make_entityset()
        
        if not train:
            assert(feature_defs is not None), "Feature defs must be provided with testing set"
            
        self.feature_defs = feature_defs
        
        # If features have already been calculated for this partition
        if os.path.exists(f'{PATH}p{partition}/fm.csv'):
            self.existing_feature_matrix = pd.read_csv(f'{PATH}p{partition}/fm.csv', nrows = 1)
            if "Unnamed: 0" in self.existing_feature_matrix:
                self.existing_feature_matrix.drop(columns  = ["Unnamed: 0"], inplace = True)
            self.feature_matrix = self.existing_feature_matrix.copy()
            self.calculated_features = list(self.feature_matrix.columns)
        else:
            self.calculated_features = []
            self.existing_feature_matrix = None
            self.feature_matrix = None
            
        if os.path.exists(f'{PATH}p{partition}/features.txt'):
            self.calculated_feature_defs = ft.load_features(f'{PATH}p{partition}/features.txt')
        else:
            self.calculated_feature_defs = []

        
    def make_entityset(self):
        es = ft.EntitySet(id = 'astro')
        es.entity_from_dataframe(entity_id = 'data', dataframe = self.data,
                                 make_index = True, index = 'index', time_index = 'mjd', 
                                 variable_types = {'detected': vtypes.Categorical,
                                                   'passband': vtypes.Categorical})
        es.entity_from_dataframe(entity_id = 'objects', dataframe = self.metadata,
                                 index = 'object_id',
                                 variable_types = {'ddf': vtypes.Categorical})
        
        es.add_relationship(ft.Relationship(es['objects']['object_id'], es['data']['object_id']))
        return es

    def deep_feature_synthesis(self, features_only = True):
        if features_only:
            self.feature_defs = ft.dfs(entityset = self.es, 
                                       agg_primitives = ['last', 'min', 'max', 'count', 'sum', 'std'],
                                       trans_primitives = ['time_since_previous', 'cum_max', 'cum_sum', 'cum_mean'],
                                       target_entity = 'objects', 
                                       features_only = features_only)
        else:
            self.feature_matrix, self.feature_defs = ft.dfs(entityset = self.es,
                                                            agg_primitives = ['last', 'min', 'max', 'count', 'sum', 'std'],
                                                            trans_primitives = ['time_since_previous', 'cum_max', 'cum_sum', 'cum_mean'],
                                                            target_entity = 'objects', 
                                                            features_only = features_only)
            
    def calculate_features(self):
        assert(self.feature_defs is not None), "Feature definitions must be provided"
        # Remove the features that have already been calculated
        self.feature_defs = [f for f in self.feature_defs if f.get_name() not in self.calculated_features]
        
        if self.feature_defs != []:
        
            # Calcuate the feature matrix
            self.feature_matrix = ft.calculate_feature_matrix(self.feature_defs, entityset = self.es)
            
            if self.existing_feature_matrix is not None:
                self.existing_feature_matrix = self.existing_feature_matrix[[c for c in self.existing_feature_matrix if c not in self.feature_matrix]]
                self.feature_matrix = pd.concat([self.feature_matrix, self.existing_feature_matrix], axis = 1)
            
            # Add the features to those already calculated for this feature matrix
            self.calculated_features = list(self.feature_matrix.columns)
            self.calculated_feature_defs.extend(self.feature_defs)
            
        else:
            print('All Features Already Calculated for Partition')
            self.feature_matrix = self.existing_feature_matrix.copy()
    
    def save_features(self):
        assert(self.feature_matrix is not None), "Feature matrix must be calculated"
                
        self.feature_matrix.to_csv(f'{PATH}p{self.partition}/fm.csv')
        ft.save_features(self.calculated_feature_defs, f'{PATH}p{self.partition}/features.txt')
        
        
    def make_predictions(self, trained_model, fit_imputer):            
        self.train_features = fit_imputer.transform(self.feature_matrix.drop(columns = ['object_id']))
        self.predictions = trained_model.predict_proba(self.train_features)
        
        self.prediction_df = pd.DataFrame(columns = ['object_id',
                                                     'class_6',
                                                     'class_15',
                                                     'class_16',
                                                     'class_42',
                                                     'class_52',
                                                     'class_53',
                                                     'class_62',
                                                     'class_64',
                                                     'class_65',
                                                     'class_67',
                                                     'class_88',
                                                     'class_90',
                                                     'class_92',
                                                     'class_95',
                                                     'class_99'])
        
        self.prediction_df['object_id'] = self.feature_matrix['object_id']
        self.prediction_df.loc[:, 'class_6': 'class_95'] = self.predictions
        self.prediction_df['class_99'] = 0
        
        self.prediction_df.to_csv(f'{PATH}p{self.partition}/predictions.csv', index = False)

# %%
sample_sub = pd.read_csv('/home/ubuntu/data/astro/sample_submission.csv', nrows = 1)
list(sample_sub.columns)
# Out:
# ['object_id',
#  'class_6',
#  'class_15',
#  'class_16',
#  'class_42',
#  'class_52',
#  'class_53',
#  'class_62',
#  'class_64',
#  'class_65',
#  'class_67',
#  'class_88',
#  'class_90',
#  'class_92',
#  'class_95',
#  'class_99']

# %%
trainp = AstroP('train', train = True)
trainp.deep_feature_synthesis()

# %%
trainp.calculated_features
# Out:
# ['object_id',
#  'ra',
#  'decl',
#  'gal_l',
#  'gal_b',
#  'hostgal_specz',
#  'hostgal_photoz',
#  'hostgal_photoz_err',
#  'distmod',
#  'mwebv',
#  'target',
#  'ddf',
#  'LAST(data.mjd)',
#  'LAST(data.flux)',
#  'LAST(data.flux_err)',
#  'LAST(data.detected)',
#  'LAST(data.passband)',
#  'MIN(data.mjd)',
#  'MIN(data.flux)',
#  'MIN(data.flux_err)',
#  'MAX(data.mjd)',
#  'MAX(data.flux)',
#  'MAX(data.flux_err)',
#  'COUNT(data)',
#  'SUM(data.mjd)',
#  'SUM(data.flux)',
#  'SUM(data.flux_err)',
#  'STD(data.mjd)',
#  'STD(data.flux)',
#  'STD(data.flux_err)',
#  'LAST(data.CUM_MAX(flux by object_id))',
#  'LAST(data.CUM_MAX(flux_err by object_id))',
#  'LAST(data.CUM_SUM(flux by object_id))',
#  'LAST(data.CUM_SUM(flux_err by object_id))',
#  'LAST(data.CUM_MEAN(flux by object_id))',
#  'LAST(data.CUM_MEAN(flux_err by object_id))',
#  'MIN(data.CUM_MAX(flux by object_id))',
#  'MIN(data.CUM_MAX(flux_err by object_id))',
#  'MIN(data.CUM_SUM(flux by object_id))',
#  'MIN(data.CUM_SUM(flux_err by object_id))',
#  'MIN(data.CUM_MEAN(flux by object_id))',
#  'MIN(data.CUM_MEAN(flux_err by object_id))',
#  'MAX(data.CUM_MAX(flux by object_id))',
#  'MAX(data.CUM_MAX(flux_err by object_id))',
#  'MAX(data.CUM_SUM(flux by object_id))',
#  'MAX(data.CUM_SUM(flux_err by object_id))',
#  'MAX(data.CUM_MEAN(flux by object_id))',
#  'MAX(data.CUM_MEAN(flux_err by object_id))',
#  'SUM(data.CUM_MAX(flux by object_id))',
#  'SUM(data.CUM_MAX(flux_err by object_id))',
#  'SUM(data.CUM_SUM(flux by object_id))',
#  'SUM(data.CUM_SUM(flux_err by object_id))',
#  'SUM(data.CUM_MEAN(flux by object_id))',
#  'SUM(data.CUM_MEAN(flux_err by object_id))',
#  'STD(data.CUM_MAX(flux by object_id))',
#  'STD(data.CUM_MAX(flux_err by object_id))',
#  'STD(data.CUM_SUM(flux by object_id))',
#  'STD(data.CUM_SUM(flux_err by object_id))',
#  'STD(data.CUM_MEAN(flux by object_id))',
#  'STD(data.CUM_MEAN(flux_err by object_id))']

# %%
trainp.calculate_features()
# Out:
# All Features Already Calculated for Partition

# %%
features = ft.load_features(f'{PATH}ptrain/features.txt')
features[0].get_name()
# Out:
# 'ra'

# %%
feature_matrix = pd.read_csv(f'{PATH}ptrain/fm.csv')
feature_matrix.head()
# Out:
#    object_id          ra       decl       gal_l      gal_b  hostgal_specz  \
# 0        615  349.046051 -61.943836  320.796530 -51.753706         0.0000
# 1        713   53.085938 -27.784405  223.525509 -54.460748         1.8181
# 2        730   33.574219  -6.579593  170.455585 -61.548219         0.2320
# 3        745    0.189873 -45.586655  328.254458 -68.969298         0.3037
# 4       1124  352.711273 -63.823658  316.922299 -51.059403         0.1934
#
#    hostgal_photoz  hostgal_photoz_err  distmod  mwebv  target  ddf  \
# 0          0.0000              0.0000      NaN  0.017      92    1
# 1          1.6267              0.2552  45.4063  0.007      88    1
# 2          0.2262              0.0157  40.2561  0.021      42    1
# 3          0.2813              1.1523  40.7951  0.007      90    1
# 4          0.2415              0.0176  40.4166  0.024      90    1
#
#    LAST(data.mjd)  LAST(data.flux)  LAST(data.flux_err)  LAST(data.detected)  \
# 0      60624.2132       157.080200             8.453112                    1
# 1      60674.0798        -8.669188             2.216094                    0
# 2      60652.1660        -1.497761             5.210212                    0
# 3      60624.0722         2.976642             4.417903                    0
# 4      60624.2132         6.331686             7.496435                    0
#
#    LAST(data.passband)  MIN(data.mjd)  MIN(data.flux)  MIN(data.flux_err)  \
# 0                    5     59750.4229    -1100.440063            2.130510
# 1                    0     59825.2600      -14.735178            0.639458
# 2                    5     59798.3205      -19.159811            0.695106
# 3                    5     59770.3662      -15.494463            0.567170
# 4                    5     59750.4229      -16.543753            0.695277
#
#    MAX(data.mjd)  MAX(data.flux)  MAX(data.flux_err)  COUNT(data)  \
# 0     60624.2132      660.626343           12.845472          352
# 1     60674.0798       14.770886            9.115748          350
# 2     60652.1660       47.310059           11.281384          330
# 3     60624.0722      220.795212           55.892746          351
# 4     60624.2132      143.600189           11.383690          352
#
#    SUM(data.mjd)  SUM(data.flux)  SUM(data.flux_err)  STD(data.mjd)  \
# 0   2.118879e+07   -43330.143249         1577.925390     310.024487
# 1   2.108987e+07     -498.172760          825.866990     310.247414
# 2   1.987324e+07      748.253237          815.450286     302.781791
# 3   2.113014e+07     3127.131254          897.007002     306.144145
# 4   2.118879e+07     2515.287161          969.057329     310.024487
#
#    STD(data.flux)  STD(data.flux_err)  LAST(data.CUM_MAX(flux by object_id))  \
# 0      394.109851            1.744747                             660.626343
# 1        6.471144            1.509888                              14.770886
# 2        8.022239            1.721134                              47.310059
# 3       27.558208            3.537324                             220.795212
# 4       20.051722            1.933837                             143.600189
#
#    LAST(data.CUM_MAX(flux_err by object_id))  \
# 0                                  12.845472
# 1                                   9.115748
# 2                                  11.281384
# 3                                  55.892746
# 4                                  11.383690
#
#    LAST(data.CUM_SUM(flux by object_id))  \
# 0                          -43330.143249
# 1                            -498.172760
# 2                             748.253237
# 3                            3127.131254
# 4                            2515.287161
#
#    LAST(data.CUM_SUM(flux_err by object_id))  \
# 0                                1577.925390
# 1                                 825.866990
# 2                                 815.450286
# 3                                 897.007002
# 4                                 969.057329
#
#    LAST(data.CUM_MEAN(flux by object_id))  \
# 0                             -123.096998
# 1                               -1.423351
# 2                                2.267434
# 3                                8.909206
# 4                                7.145702
#
#    LAST(data.CUM_MEAN(flux_err by object_id))  \
# 0                                    4.482743
# 1                                    2.359620
# 2                                    2.471061
# 3                                    2.555576
# 4                                    2.753004
#
#    MIN(data.CUM_MAX(flux by object_id))  \
# 0                           -544.810303
# 1                              9.110147
# 2                              1.177371
# 3                              0.161398
# 4                              1.929243
#
#    MIN(data.CUM_MAX(flux_err by object_id))  \
# 0                                  3.622952
# 1                                  1.013889
# 2                                  1.364300
# 3                                  0.619084
# 4                                  1.531847
#
#    MIN(data.CUM_SUM(flux by object_id))  \
# 0                         -47609.703104
# 1                           -498.172760
# 2                            -21.964732
# 3                             -5.122443
# 4                            -21.471966
#
#    MIN(data.CUM_SUM(flux_err by object_id))  \
# 0                                  3.622952
# 1                                  1.013889
# 2                                  1.364300
# 3                                  0.619084
# 4                                  1.531847
#
#    MIN(data.CUM_MEAN(flux by object_id))  \
# 0                            -680.622314
# 1                              -1.423351
# 2                              -1.178117
# 3                              -0.720523
# 4                              -3.545689
#
#    MIN(data.CUM_MEAN(flux_err by object_id))  \
# 0                                   3.622952
# 1                                   1.013889
# 2                                   1.261774
# 3                                   0.610841
# 4                                   1.531847
#
#    MAX(data.CUM_MAX(flux by object_id))  \
# 0                            660.626343
# 1                             14.770886
# 2                             47.310059
# 3                            220.795212
# 4                            143.600189
#
#    MAX(data.CUM_MAX(flux_err by object_id))  \
# 0                                 12.845472
# 1                                  9.115748
# 2                                 11.281384
# 3                                 55.892746
# 4                                 11.383690
#
#    MAX(data.CUM_SUM(flux by object_id))  \
# 0                           -544.810303
# 1                            657.694251
# 2                            752.289347
# 3                           3145.846778
# 4                           2515.287161
#
#    MAX(data.CUM_SUM(flux_err by object_id))  \
# 0                               1577.925390
# 1                                825.866990
# 2                                815.450286
# 3                                897.007002
# 4                                969.057329
#
#    MAX(data.CUM_MEAN(flux by object_id))  \
# 0                            -123.096998
# 1                               9.110147
# 2                               2.423176
# 3                              14.895624
# 4                               7.376462
#
#    MAX(data.CUM_MEAN(flux_err by object_id))  \
# 0                                   6.093141
# 1                                   2.857584
# 2                                   2.852247
# 3                                   2.778598
# 4                                   4.111077
#
#    SUM(data.CUM_MAX(flux by object_id))  \
# 0                         188975.718945
# 1                           4936.586924
# 2                           7373.074188
# 3                          51375.481456
# 4                          19640.701538
#
#    SUM(data.CUM_MAX(flux_err by object_id))  \
# 0                               4255.575773
# 1                               3038.174287
# 2                               2999.147222
# 3                               7028.121168
# 4                               3818.555806
#
#    SUM(data.CUM_SUM(flux by object_id))  \
# 0                         -1.156206e+07
# 1                          9.574745e+04
# 2                          6.530834e+04
# 3                          6.275523e+05
# 4                          2.347998e+05
#
#    SUM(data.CUM_SUM(flux_err by object_id))  \
# 0                             281899.617014
# 1                             145632.756253
# 2                             136359.215481
# 3                             151328.660460
# 4                             172192.258916
#
#    SUM(data.CUM_MEAN(flux by object_id))  \
# 0                          -86522.016147
# 1                             981.928803
# 2                             266.444608
# 3                            2718.724880
# 4                             794.732089
#
#    SUM(data.CUM_MEAN(flux_err by object_id))  \
# 0                                1625.083610
# 1                                 826.137140
# 2                                 817.541390
# 3                                 843.419415
# 4                                 987.490122
#
#    STD(data.CUM_MAX(flux by object_id))  \
# 0                            286.469679
# 1                              1.187667
# 2                             17.189027
# 3                            100.229520
# 4                             63.265464
#
#    STD(data.CUM_MAX(flux_err by object_id))  \
# 0                                  0.986632
# 1                                  1.059203
# 2                                  2.247293
# 3                                 17.822295
# 4                                  0.950609
#
#    STD(data.CUM_SUM(flux by object_id))  \
# 0                          11859.311520
# 1                            314.762389
# 2                            286.501217
# 3                           1417.156478
# 4                            960.678845
#
#    STD(data.CUM_SUM(flux_err by object_id))  \
# 0                                456.138608
# 1                                240.883371
# 2                                241.159072
# 3                                262.779735
# 4                                280.168342
#
#    STD(data.CUM_MEAN(flux by object_id))  \
# 0                             122.080641
# 1                               2.295335
# 2                               0.964939
# 3                               5.851403
# 4                               3.167277
#
#    STD(data.CUM_MEAN(flux_err by object_id))
# 0                                   0.243272
# 1                                   0.131081
# 2                                   0.134242
# 3                                   0.227629
# 4                                   0.170290

# %%
trainp.deep_feature_synthesis()
trainp.feature_defs
# Out:
# [<Feature: ra>,
#  <Feature: decl>,
#  <Feature: gal_l>,
#  <Feature: gal_b>,
#  <Feature: hostgal_specz>,
#  <Feature: hostgal_photoz>,
#  <Feature: hostgal_photoz_err>,
#  <Feature: distmod>,
#  <Feature: mwebv>,
#  <Feature: ddf>,
#  <Feature: LAST(data.mjd)>,
#  <Feature: LAST(data.flux)>,
#  <Feature: LAST(data.flux_err)>,
#  <Feature: LAST(data.detected)>,
#  <Feature: LAST(data.passband)>,
#  <Feature: MIN(data.mjd)>,
#  <Feature: MIN(data.flux)>,
#  <Feature: MIN(data.flux_err)>,
#  <Feature: MAX(data.mjd)>,
#  <Feature: MAX(data.flux)>,
#  <Feature: MAX(data.flux_err)>,
#  <Feature: COUNT(data)>,
#  <Feature: SUM(data.mjd)>,
#  <Feature: SUM(data.flux)>,
#  <Feature: SUM(data.flux_err)>,
#  <Feature: STD(data.mjd)>,
#  <Feature: STD(data.flux)>,
#  <Feature: STD(data.flux_err)>,
#  <Feature: LAST(data.CUM_MAX(flux by object_id))>,
#  <Feature: LAST(data.CUM_MAX(flux_err by object_id))>,
#  <Feature: LAST(data.CUM_SUM(flux by object_id))>,
#  <Feature: LAST(data.CUM_SUM(flux_err by object_id))>,
#  <Feature: LAST(data.CUM_MEAN(flux by object_id))>,
#  <Feature: LAST(data.CUM_MEAN(flux_err by object_id))>,
#  <Feature: MIN(data.CUM_MAX(flux by object_id))>,
#  <Feature: MIN(data.CUM_MAX(flux_err by object_id))>,
#  <Feature: MIN(data.CUM_SUM(flux by object_id))>,
#  <Feature: MIN(data.CUM_SUM(flux_err by object_id))>,
#  <Feature: MIN(data.CUM_MEAN(flux by object_id))>,
#  <Feature: MIN(data.CUM_MEAN(flux_err by object_id))>,
#  <Feature: MAX(data.CUM_MAX(flux by object_id))>,
#  <Feature: MAX(data.CUM_MAX(flux_err by object_id))>,
#  <Feature: MAX(data.CUM_SUM(flux by object_id))>,
#  <Feature: MAX(data.CUM_SUM(flux_err by object_id))>,
#  <Feature: MAX(data.CUM_MEAN(flux by object_id))>,
#  <Feature: MAX(data.CUM_MEAN(flux_err by object_id))>,
#  <Feature: SUM(data.CUM_MAX(flux by object_id))>,
#  <Feature: SUM(data.CUM_MAX(flux_err by object_id))>,
#  <Feature: SUM(data.CUM_SUM(flux by object_id))>,
#  <Feature: SUM(data.CUM_SUM(flux_err by object_id))>,
#  <Feature: SUM(data.CUM_MEAN(flux by object_id))>,
#  <Feature: SUM(data.CUM_MEAN(flux_err by object_id))>,
#  <Feature: STD(data.CUM_MAX(flux by object_id))>,
#  <Feature: STD(data.CUM_MAX(flux_err by object_id))>,
#  <Feature: STD(data.CUM_SUM(flux by object_id))>,
#  <Feature: STD(data.CUM_SUM(flux_err by object_id))>,
#  <Feature: STD(data.CUM_MEAN(flux by object_id))>,
#  <Feature: STD(data.CUM_MEAN(flux_err by object_id))>]

# %%
trainp.es
# Out:
# Entityset: astro
#   Entities:
#     data [Rows: 1421705, Columns: 7]
#     objects [Rows: 7848, Columns: 11]
#   Relationships:
#     data.object_id -> objects.object_id

# %%
trainp.es['data']
# Out:
# Entity: data
#   Variables:
#     index (dtype: index)
#     object_id (dtype: id)
#     mjd (dtype: numeric_time_index)
#     flux (dtype: numeric)
#     flux_err (dtype: numeric)
#     detected (dtype: categorical)
#     passband (dtype: categorical)
#   Shape:
#     (Rows: 1421705, Columns: 7)

# %%
partitions = list(range(10))

for p in partitions:
    astrop = AstroP(partition=p, train = False, feature_defs = trainp.feature_defs)
    astrop.calculate_features()
    astrop.save_features()

# %%
train_meta.head()
# Out:
#    object_id          ra       decl       gal_l      gal_b  ddf  \
# 0        615  349.046051 -61.943836  320.796530 -51.753706    1
# 1        713   53.085938 -27.784405  223.525509 -54.460748    1
# 2        730   33.574219  -6.579593  170.455585 -61.548219    1
# 3        745    0.189873 -45.586655  328.254458 -68.969298    1
# 4       1124  352.711273 -63.823658  316.922299 -51.059403    1
#
#    hostgal_specz  hostgal_photoz  hostgal_photoz_err  distmod  mwebv  target
# 0         0.0000          0.0000              0.0000      NaN  0.017      92
# 1         1.8181          1.6267              0.2552  45.4063  0.007      88
# 2         0.2320          0.2262              0.0157  40.2561  0.021      42
# 3         0.3037          0.2813              1.1523  40.7951  0.007      90
# 4         0.1934          0.2415              0.0176  40.4166  0.024      90

# %%
pd.options.display.max_columns = 100
feature_matrix.head()
# Out:
#    object_id          ra       decl       gal_l      gal_b  hostgal_specz  \
# 0        615  349.046051 -61.943836  320.796530 -51.753706         0.0000
# 1        713   53.085938 -27.784405  223.525509 -54.460748         1.8181
# 2        730   33.574219  -6.579593  170.455585 -61.548219         0.2320
# 3        745    0.189873 -45.586655  328.254458 -68.969298         0.3037
# 4       1124  352.711273 -63.823658  316.922299 -51.059403         0.1934
#
#    hostgal_photoz  hostgal_photoz_err  distmod  mwebv  target  ddf  \
# 0          0.0000              0.0000      NaN  0.017      92    1
# 1          1.6267              0.2552  45.4063  0.007      88    1
# 2          0.2262              0.0157  40.2561  0.021      42    1
# 3          0.2813              1.1523  40.7951  0.007      90    1
# 4          0.2415              0.0176  40.4166  0.024      90    1
#
#    LAST(data.mjd)  LAST(data.flux)  LAST(data.flux_err)  LAST(data.detected)  \
# 0      60624.2132       157.080200             8.453112                    1
# 1      60674.0798        -8.669188             2.216094                    0
# 2      60652.1660        -1.497761             5.210212                    0
# 3      60624.0722         2.976642             4.417903                    0
# 4      60624.2132         6.331686             7.496435                    0
#
#    LAST(data.passband)  MIN(data.mjd)  MIN(data.flux)  MIN(data.flux_err)  \
# 0                    5     59750.4229    -1100.440063            2.130510
# 1                    0     59825.2600      -14.735178            0.639458
# 2                    5     59798.3205      -19.159811            0.695106
# 3                    5     59770.3662      -15.494463            0.567170
# 4                    5     59750.4229      -16.543753            0.695277
#
#    MAX(data.mjd)  MAX(data.flux)  MAX(data.flux_err)  COUNT(data)  \
# 0     60624.2132      660.626343           12.845472          352
# 1     60674.0798       14.770886            9.115748          350
# 2     60652.1660       47.310059           11.281384          330
# 3     60624.0722      220.795212           55.892746          351
# 4     60624.2132      143.600189           11.383690          352
#
#    SUM(data.mjd)  SUM(data.flux)  SUM(data.flux_err)  STD(data.mjd)  \
# 0   2.118879e+07   -43330.143249         1577.925390     310.024487
# 1   2.108987e+07     -498.172760          825.866990     310.247414
# 2   1.987324e+07      748.253237          815.450286     302.781791
# 3   2.113014e+07     3127.131254          897.007002     306.144145
# 4   2.118879e+07     2515.287161          969.057329     310.024487
#
#    STD(data.flux)  STD(data.flux_err)  LAST(data.CUM_MAX(flux by object_id))  \
# 0      394.109851            1.744747                             660.626343
# 1        6.471144            1.509888                              14.770886
# 2        8.022239            1.721134                              47.310059
# 3       27.558208            3.537324                             220.795212
# 4       20.051722            1.933837                             143.600189
#
#    LAST(data.CUM_MAX(flux_err by object_id))  \
# 0                                  12.845472
# 1                                   9.115748
# 2                                  11.281384
# 3                                  55.892746
# 4                                  11.383690
#
#    LAST(data.CUM_SUM(flux by object_id))  \
# 0                          -43330.143249
# 1                            -498.172760
# 2                             748.253237
# 3                            3127.131254
# 4                            2515.287161
#
#    LAST(data.CUM_SUM(flux_err by object_id))  \
# 0                                1577.925390
# 1                                 825.866990
# 2                                 815.450286
# 3                                 897.007002
# 4                                 969.057329
#
#    LAST(data.CUM_MEAN(flux by object_id))  \
# 0                             -123.096998
# 1                               -1.423351
# 2                                2.267434
# 3                                8.909206
# 4                                7.145702
#
#    LAST(data.CUM_MEAN(flux_err by object_id))  \
# 0                                    4.482743
# 1                                    2.359620
# 2                                    2.471061
# 3                                    2.555576
# 4                                    2.753004
#
#    MIN(data.CUM_MAX(flux by object_id))  \
# 0                           -544.810303
# 1                              9.110147
# 2                              1.177371
# 3                              0.161398
# 4                              1.929243
#
#    MIN(data.CUM_MAX(flux_err by object_id))  \
# 0                                  3.622952
# 1                                  1.013889
# 2                                  1.364300
# 3                                  0.619084
# 4                                  1.531847
#
#    MIN(data.CUM_SUM(flux by object_id))  \
# 0                         -47609.703104
# 1                           -498.172760
# 2                            -21.964732
# 3                             -5.122443
# 4                            -21.471966
#
#    MIN(data.CUM_SUM(flux_err by object_id))  \
# 0                                  3.622952
# 1                                  1.013889
# 2                                  1.364300
# 3                                  0.619084
# 4                                  1.531847
#
#    MIN(data.CUM_MEAN(flux by object_id))  \
# 0                            -680.622314
# 1                              -1.423351
# 2                              -1.178117
# 3                              -0.720523
# 4                              -3.545689
#
#    MIN(data.CUM_MEAN(flux_err by object_id))  \
# 0                                   3.622952
# 1                                   1.013889
# 2                                   1.261774
# 3                                   0.610841
# 4                                   1.531847
#
#    MAX(data.CUM_MAX(flux by object_id))  \
# 0                            660.626343
# 1                             14.770886
# 2                             47.310059
# 3                            220.795212
# 4                            143.600189
#
#    MAX(data.CUM_MAX(flux_err by object_id))  \
# 0                                 12.845472
# 1                                  9.115748
# 2                                 11.281384
# 3                                 55.892746
# 4                                 11.383690
#
#    MAX(data.CUM_SUM(flux by object_id))  \
# 0                           -544.810303
# 1                            657.694251
# 2                            752.289347
# 3                           3145.846778
# 4                           2515.287161
#
#    MAX(data.CUM_SUM(flux_err by object_id))  \
# 0                               1577.925390
# 1                                825.866990
# 2                                815.450286
# 3                                897.007002
# 4                                969.057329
#
#    MAX(data.CUM_MEAN(flux by object_id))  \
# 0                            -123.096998
# 1                               9.110147
# 2                               2.423176
# 3                              14.895624
# 4                               7.376462
#
#    MAX(data.CUM_MEAN(flux_err by object_id))  \
# 0                                   6.093141
# 1                                   2.857584
# 2                                   2.852247
# 3                                   2.778598
# 4                                   4.111077
#
#    SUM(data.CUM_MAX(flux by object_id))  \
# 0                         188975.718945
# 1                           4936.586924
# 2                           7373.074188
# 3                          51375.481456
# 4                          19640.701538
#
#    SUM(data.CUM_MAX(flux_err by object_id))  \
# 0                               4255.575773
# 1                               3038.174287
# 2                               2999.147222
# 3                               7028.121168
# 4                               3818.555806
#
#    SUM(data.CUM_SUM(flux by object_id))  \
# 0                         -1.156206e+07
# 1                          9.574745e+04
# 2                          6.530834e+04
# 3                          6.275523e+05
# 4                          2.347998e+05
#
#    SUM(data.CUM_SUM(flux_err by object_id))  \
# 0                             281899.617014
# 1                             145632.756253
# 2                             136359.215481
# 3                             151328.660460
# 4                             172192.258916
#
#    SUM(data.CUM_MEAN(flux by object_id))  \
# 0                          -86522.016147
# 1                             981.928803
# 2                             266.444608
# 3                            2718.724880
# 4                             794.732089
#
#    SUM(data.CUM_MEAN(flux_err by object_id))  \
# 0                                1625.083610
# 1                                 826.137140
# 2                                 817.541390
# 3                                 843.419415
# 4                                 987.490122
#
#    STD(data.CUM_MAX(flux by object_id))  \
# 0                            286.469679
# 1                              1.187667
# 2                             17.189027
# 3                            100.229520
# 4                             63.265464
#
#    STD(data.CUM_MAX(flux_err by object_id))  \
# 0                                  0.986632
# 1                                  1.059203
# 2                                  2.247293
# 3                                 17.822295
# 4                                  0.950609
#
#    STD(data.CUM_SUM(flux by object_id))  \
# 0                          11859.311520
# 1                            314.762389
# 2                            286.501217
# 3                           1417.156478
# 4                            960.678845
#
#    STD(data.CUM_SUM(flux_err by object_id))  \
# 0                                456.138608
# 1                                240.883371
# 2                                241.159072
# 3                                262.779735
# 4                                280.168342
#
#    STD(data.CUM_MEAN(flux by object_id))  \
# 0                             122.080641
# 1                               2.295335
# 2                               0.964939
# 3                               5.851403
# 4                               3.167277
#
#    STD(data.CUM_MEAN(flux_err by object_id))
# 0                                   0.243272
# 1                                   0.131081
# 2                                   0.134242
# 3                                   0.227629
# 4                                   0.170290

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import SimpleImputer

imputer = SimpleImputer()
train_features = imputer.fit_transform(feature_matrix.drop(columns = ['object_id', 'target']))
model = RandomForestClassifier(n_estimators = 100, max_depth = 20)
model.fit(train_features, np.array(train_meta['target']))
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=20, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
train_features.shape
# Out:
# (7848, 58)

# %%
feature_matrix.shape
# Out:
# (7848, 60)

# %%
fm.shape
# Out:
# (1, 60)

# %%
trainp.make_predictions(model, imputer)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-239-a4da4cbfb76e> in <module>
# ----> 1 trainp.make_predictions(model, imputer)
#
# <ipython-input-225-d99c8c15fcb6> in make_predictions(self, trained_model, fit_imputer)
#      93
#      94     def make_predictions(self, trained_model, fit_imputer):
# ---> 95         self.train_features = fit_imputer.transform(self.feature_matrix.drop(columns = ['object_id']))
#      96         self.predictions = trained_model.predict_proba(self.train_features)
#      97
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/sklearn/impute.py in transform(self, X)
#     367         if X.shape[1] != statistics.shape[0]:
#     368             raise ValueError("X has %d features per sample, expected %d"
# --> 369                              % (X.shape[1], self.statistics_.shape[0]))
#     370
#     371         # Delete the invalid columns if strategy is not constant
#
# ValueError: X has 59 features per sample, expected 58

# %%
trainp.train_features.shape

# %%
feature_matrix.head()

# %%
fm = pd.read_csv('/home/ubuntu/data/astro/partitions/p0/fm.csv')
fm.head()

# %%
for c in feature_matrix:
    if c not in fm:
        print(c)

# %%
s = imputer.transform

# %%
partitions = list(range(10))

for p in partitions:
    astrop = AstroP(partition=p, train = False, feature_defs = trainp.feature_defs)
    astrop.calculate_features()
    astrop.save_features()
    astrop.make_predictions(model, imputer)
# Out:
# All Features Already Calculated for Partition
# All Features Already Calculated for Partition
# All Features Already Calculated for Partition
# All Features Already Calculated for Partition
# All Features Already Calculated for Partition
# All Features Already Calculated for Partition
# All Features Already Calculated for Partition
# All Features Already Calculated for Partition
# All Features Already Calculated for Partition
# All Features Already Calculated for Partition

# %%
astrop.feature_matrix.head()
# Out:
#    object_id          ra       decl      gal_l      gal_b  hostgal_specz  \
# 0       2000  349.046051 -61.943836  320.79653 -51.753706            NaN
#
#    hostgal_photoz  hostgal_photoz_err  distmod  mwebv  ddf  LAST(data.mjd)  \
# 0          0.6559               0.024  42.9743  0.017    1      60624.2132
#
#    LAST(data.flux)  LAST(data.flux_err)  LAST(data.detected)  \
# 0        -4.061143             7.437538                    0
#
#    LAST(data.passband)  MIN(data.mjd)  MIN(data.flux)  MIN(data.flux_err)  \
# 0                    5     59750.4229      -10.485474            0.666862
#
#    MAX(data.mjd)  MAX(data.flux)  MAX(data.flux_err)  COUNT(data)  \
# 0     60624.2132       21.316643           11.294422          352
#
#    SUM(data.mjd)  SUM(data.flux)  SUM(data.flux_err)  STD(data.mjd)  \
# 0   2.118879e+07      466.790663          954.267909     310.024487
#
#    STD(data.flux)  STD(data.flux_err)  LAST(data.CUM_MAX(flux by object_id))  \
# 0         4.25823            1.924752                              21.316643
#
#    LAST(data.CUM_MAX(flux_err by object_id))  \
# 0                                  11.294422
#
#    LAST(data.CUM_SUM(flux by object_id))  \
# 0                             466.790663
#
#    LAST(data.CUM_SUM(flux_err by object_id))  \
# 0                                 954.267909
#
#    LAST(data.CUM_MEAN(flux by object_id))  \
# 0                                 1.32611
#
#    LAST(data.CUM_MEAN(flux_err by object_id))  \
# 0                                    2.710988
#
#    MIN(data.CUM_MAX(flux by object_id))  \
# 0                              0.655506
#
#    MIN(data.CUM_MAX(flux_err by object_id))  \
# 0                                  1.507761
#
#    MIN(data.CUM_SUM(flux by object_id))  \
# 0                             -9.787856
#
#    MIN(data.CUM_SUM(flux_err by object_id))  \
# 0                                  1.507761
#
#    MIN(data.CUM_MEAN(flux by object_id))  \
# 0                              -2.259973
#
#    MIN(data.CUM_MEAN(flux_err by object_id))  \
# 0                                   1.507761
#
#    MAX(data.CUM_MAX(flux by object_id))  \
# 0                             21.316643
#
#    MAX(data.CUM_MAX(flux_err by object_id))  \
# 0                                 11.294422
#
#    MAX(data.CUM_SUM(flux by object_id))  \
# 0                            485.119027
#
#    MAX(data.CUM_SUM(flux_err by object_id))  \
# 0                                954.267909
#
#    MAX(data.CUM_MEAN(flux by object_id))  \
# 0                               5.076399
#
#    MAX(data.CUM_MEAN(flux_err by object_id))  \
# 0                                   4.062942
#
#    SUM(data.CUM_MAX(flux by object_id))  \
# 0                           7060.415514
#
#    SUM(data.CUM_MAX(flux_err by object_id))  \
# 0                               3786.604455
#
#    SUM(data.CUM_SUM(flux by object_id))  \
# 0                         138230.513719
#
#    SUM(data.CUM_SUM(flux_err by object_id))  \
# 0                             169807.305238
#
#    SUM(data.CUM_MEAN(flux by object_id))  \
# 0                             898.740757
#
#    SUM(data.CUM_MEAN(flux_err by object_id))  \
# 0                                 974.688414
#
#    STD(data.CUM_MAX(flux by object_id))  \
# 0                              4.346168
#
#    STD(data.CUM_MAX(flux_err by object_id))  \
# 0                                  0.947024
#
#    STD(data.CUM_SUM(flux by object_id))  \
# 0                            142.473534
#
#    STD(data.CUM_SUM(flux_err by object_id))  \
# 0                                275.703799
#
#    STD(data.CUM_MEAN(flux by object_id))  \
# 0                               1.352682
#
#    STD(data.CUM_MEAN(flux_err by object_id))
# 0                                   0.170264

# %%
for c in feature_matrix:
    if c not in astrop.feature_matrix:
        print(c)
# Out:
# target

# %%
import findspark
findspark.init('/usr/local/spark-2.3.2-bin-hadoop2.7/')
import pyspark

# %%
spark_conf = pyspark.SparkConf()
# spark_conf.set('num.executors', 1)
spark_conf.set('spark.executor.memory', '56G')
spark_conf.getAll()
# Out:
# [('spark.master', 'local[*]'),
#  ('spark.submit.deployMode', 'client'),
#  ('spark.executor.memory', '56G'),
#  ('spark.ui.showConsoleProgress', 'true'),
#  ('spark.app.name', 'pyspark-shell')]

# %%
sc.stop()
sc = pyspark.SparkContext(master = 'spark://ip-172-31-79-46.ec2.internal:7077',
                                     appName = 'astro', conf = spark_conf)

# %%
def partition_prediction(p):
    astrop = AstroP(partition=p, train = False, feature_defs = trainp.feature_defs)
    astrop.calculate_features()
    astrop.save_features()
    astrop.make_predictions(model, imputer)

# %%
sc.parallelize(list(range(1000)), numSlices = 1000).\
   map(partition_prediction).collect()
sc.stop()
